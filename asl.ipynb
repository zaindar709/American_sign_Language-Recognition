# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/sign_mnist_train.csv /content/amer_sign3.png /content/american_sign_language.PNG /content/sign_mnist_test.csv /content/amer_sign2.png'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
import keras
from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_df=pd.read_csv('/content/sign_mnist_train.csv')
test_df=pd.read_csv('/content/sign_mnist_test.csv')
train_df.info()
test_df.info()
train_df.describe()
train_df.head(6)
train_label=train_df['label']
train_label.head()
trainset=train_df.drop(['label'],axis=1)
trainset.head()
X_train = trainset.values
X_train = trainset.values.reshape(-1,28,28,1)
print(X_train.shape)
test_label=test_df['label']
X_test=test_df.drop(['label'],axis=1)
print(X_test.shape)
X_test.head()
from sklearn.preprocessing import LabelBinarizer
lb=LabelBinarizer()
y_train=lb.fit_transform(train_label)
y_test=lb.fit_transform(test_label)
y_train
X_test=X_test.values.reshape(-1,28,28,1)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
train_datagen = ImageDataGenerator(rescale = 1./255,
                                  rotation_range = 0,
                                  height_shift_range=0.2,
                                  width_shift_range=0.2,
                                  shear_range=0,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  fill_mode='nearest')

X_test=X_test/255
fig,axe=plt.subplots(2,2)
fig.suptitle('Preview of dataset')
axe[0,0].imshow(X_train[0].reshape(28,28),cmap='gray')
axe[0,0].set_title('label: 3  letter: C')
axe[0,1].imshow(X_train[1].reshape(28,28),cmap='gray')
axe[0,1].set_title('label: 6  letter: F')
axe[1,0].imshow(X_train[2].reshape(28,28),cmap='gray')
axe[1,0].set_title('label: 2  letter: B')
axe[1,1].imshow(X_train[4].reshape(28,28),cmap='gray')
axe[1,1].set_title('label: 13  letter: M')
sns.countplot(train_label)
plt.title("Frequency of each label")
model=Sequential()
model.add(Conv2D(128,kernel_size=(5,5),
                 strides=1,padding='same',activation='relu',input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(3,3),strides=2,padding='same'))
model.add(Conv2D(64,kernel_size=(2,2),
                strides=1,activation='relu',padding='same'))
model.add(MaxPool2D((2,2),2,padding='same'))
model.add(Conv2D(32,kernel_size=(2,2),
                strides=1,activation='relu',padding='same'))
model.add(MaxPool2D((2,2),2,padding='same'))

model.add(Flatten())
model.add(Dense(units=512,activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=24,activation='softmax'))
model.summary()
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_datagen.flow(X_train,y_train,batch_size=200),
         epochs = 35,
          validation_data=(X_test,y_test),
          shuffle=1
         )
(ls,acc)=model.evaluate(x=X_test,y=y_test)
print('MODEL ACCURACY = {}%'.format(acc*100))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072 entries, 0 to 2071
# Columns: 785 entries, label to pixel784
# dtypes: float64(677), int64(108)
# memory usage: 12.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB
# (2072, 28, 28, 1)
# (7172, 784)
# (2072, 28, 28, 1) (2072, 24) (7172, 28, 28, 1) (7172, 24)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       3328
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        32832
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          8224
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 319352 (1.22 MB)
# Trainable params: 319352 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0430 - val_loss: nan - val_accuracy: 0.0462
# Epoch 2/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 3/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 4/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 5/35
# 11/11 [==============================] - 20s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 6/35
# 11/11 [==============================] - 14s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 7/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 8/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 9/35
# 11/11 [==============================] - 18s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 11/35
# 11/11 [==============================] - 12s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 12/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 13/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 14/35
# 11/11 [==============================] - 14s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 15/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 16/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 17/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 18/35
# 11/11 [==============================] - 12s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 19/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 20/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 21/35
# 11/11 [==============================] - 12s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 22/35
# 11/11 [==============================] - 12s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 23/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 24/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 25/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 26/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 27/35
# 11/11 [==============================] - 12s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 28/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 29/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 30/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 31/35
# 11/11 [==============================] - 14s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 32/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 33/35
# 11/11 [==============================] - 13s 1s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 34/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# Epoch 35/35
# 11/11 [==============================] - 17s 2s/step - loss: nan - accuracy: 0.0420 - val_loss: nan - val_accuracy: 0.0462
# 225/225 [==============================] - 6s 28ms/step - loss: nan - accuracy: 0.0462
# MODEL ACCURACY = 4.615170136094093%
